# %%
import base64

# %%
ctext = str.encode("...")

# %%
ctext_utf = ctext.decode("utf-8")
ctext_ascii = ctext.decode("ascii")
print(ctext_utf)
print(ctext_ascii)
print(base64.b64decode(ctext))
# Out:
# ...
# ...
# ...
